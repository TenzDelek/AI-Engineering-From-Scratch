# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(-0.02502626135999958), np.float64(0.9873211671894548))

# %%
# %timeit np.random.randn(10000)
# %timeit runs the code many times and averages, use for microbenchmarks
# Out:
# 103 μs ± 389 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%time 
np.random.randn(10000)
# %%time runs it once. use for training runs
# Out:
# CPU times: user 369 μs, sys: 66 μs, total: 435 μs
# Wall time: 254 μs
# array([ 1.06537657, -1.52889255,  0.74632362, ...,  1.40444654,
#        -1.05587403,  0.0334663 ], shape=(10000,))

# %%
# %matplotlib inline

# %%
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})
df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 2))
plt.plot([1, 4, 3, 5], [1, 2, 2, 3])
plt.title("Inline Plot by Tenzin")
plt.show()
